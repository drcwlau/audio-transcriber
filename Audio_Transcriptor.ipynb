# %% [markdown]
# <a href="https://colab.research.google.com/github/drcwlau/audio-transcriber/blob/main/Audio_Transcriptor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai-whisper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 27.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=fbfd9e81ab91534c7c8cbec03de6260715dcc1bdd7baf1053e092e26e7f2ea1a
#   Stored in directory: /root/.cache/pip/wheels/61/d2/20/09ec9bef734d126cba375b15898010b6cc28578d8afdde5869
# Successfully built openai-whisper
# ...

# %%
import os
import sys
import subprocess

def transcribe_audio_whisper(file_path, language='zh', model='tiny'):
    """Transcribe using OpenAI Whisper - TINY model for speed"""

    try:
        print(f"Using Whisper model: {model}")
        result = subprocess.run(
            ['whisper', file_path,
             '--model', model,
             '--output_format', 'txt',
             '--output_dir', '.',
             '--language', language],
            capture_output=True,
            text=True,
            timeout=1800
        )

        if result.returncode == 0:
            print(f"✅ Transcription completed successfully")
            print(result.stdout)
            return True
        else:
            print(f"❌ Whisper error: {result.stderr}")
            return False
    except subprocess.TimeoutExpired:
        print("❌ Transcription timed out")
        return False
    except Exception as e:
        print(f"❌ Error: {e}")
        return False

def main(audio_file_path, language='zh'):
    if not os.path.exists(audio_file_path):
        print("Error: Audio file does not exist.")
        return

    file_size_mb = os.path.getsize(audio_file_path) / (1024 * 1024)
    print(f"📁 File size: {file_size_mb:.2f} MB")
    print("🎙️  Processing with Whisper TINY model (fastest)...")

    success = transcribe_audio_whisper(audio_file_path, language=language, model='tiny')

    if success:
        print("✅ Transcription saved!")
    else:
        print("❌ Transcription failed!")

if __name__ == "__main__":
    if len(sys.argv) > 1:
        audio_file = sys.argv[1]
    else:
        audio_file = '/REC_002.mp3'

    main(audio_file, language='zh')
# Out:
# Error: Audio file does not exist.

# %%
import os
import sys
import subprocess

def transcribe_audio_whisper(file_path, language='zh', model='tiny'):
    """Transcribe using OpenAI Whisper - TINY model for speed"""

    try:
        print(f"Using Whisper model: {model}")
        result = subprocess.run(
            ['whisper', file_path,
             '--model', model,
             '--output_format', 'txt',
             '--output_dir', '.',
             '--language', language],
            capture_output=True,
            text=True,
            timeout=1800
        )

        if result.returncode == 0:
            print(f"✅ Transcription completed successfully")
            print(result.stdout)
            return True
        else:
            print(f"❌ Whisper error: {result.stderr}")
            return False
    except subprocess.TimeoutExpired:
        print("❌ Transcription timed out")
        return False
    except Exception as e:
        print(f"❌ Error: {e}")
        return False

def main(audio_file_path, language='zh'):
    if not os.path.exists(audio_file_path):
        print("Error: Audio file does not exist.")
        return

    file_size_mb = os.path.getsize(audio_file_path) / (1024 * 1024)
    print(f"📁 File size: {file_size_mb:.2f} MB")
    print("🎙️  Processing with Whisper TINY model (fastest)...")

    success = transcribe_audio_whisper(audio_file_path, language=language, model='tiny')

    if success:
        print("✅ Transcription saved!")
    else:
        print("❌ Transcription failed!")

if __name__ == "__main__":
    if len(sys.argv) > 1:
        audio_file = sys.argv[1]
    else:
        audio_file = '/REC_002.mp3'

    main(audio_file, language='zh')
# Out:
# Error: Audio file does not exist.

# %%
import os
import sys
import subprocess

def transcribe_audio_whisper(file_path, language='zh', model='tiny'):
    """Transcribe using OpenAI Whisper - TINY model for speed"""

    try:
        print(f"Using Whisper model: {model}")
        result = subprocess.run(
            ['whisper', file_path,
             '--model', model,
             '--output_format', 'txt',
             '--output_dir', '.',
             '--language', language],
            capture_output=True,
            text=True,
            timeout=1800
        )

        if result.returncode == 0:
            print(f"✅ Transcription completed successfully")
            print(result.stdout)
            return True
        else:
            print(f"❌ Whisper error: {result.stderr}")
            return False
    except subprocess.TimeoutExpired:
        print("❌ Transcription timed out")
        return False
    except Exception as e:
        print(f"❌ Error: {e}")
        return False

def main(audio_file_path, language='zh'):
    if not os.path.exists(audio_file_path):
        print("Error: Audio file does not exist.")
        return

    file_size_mb = os.path.getsize(audio_file_path) / (1024 * 1024)
    print(f"📁 File size: {file_size_mb:.2f} MB")
    print("🎙️  Processing with Whisper TINY model (fastest)...")

    success = transcribe_audio_whisper(audio_file_path, language=language, model='base')

    if success:
        print("✅ Transcription saved!")
    else:
        print("❌ Transcription failed!")

if __name__ == "__main__":
    if len(sys.argv) > 1:
        audio_file = '/content/REC_002.mp3' #sys.argv[1]
    else:
        audio_file = '/content/REC_002.mp3'

    main(audio_file, language='zh')
# Out:
# 📁 File size: 1.08 MB
# 🎙️  Processing with Whisper TINY model (fastest)...
# Using Whisper model: base
# ✅ Transcription completed successfully
# [00:00.000 --> 00:08.000] 此之以先生說了,變病和變症相結合是中期結合的初步徒
# [00:08.000 --> 00:15.000] 現在又過去五十年,一過去七十幾年,五二三七十四年,還是初步徒徑嗎?
# [00:15.000 --> 00:22.000] 所以不要在病症結合,要走下一個模式
# [00:22.000 --> 00:33.000] 你看我們這個模式,一個病,三十幾個症,三十幾個症,我們現在三大學會發了一千七百多個標準
# [00:33.000 --> 00:38.000] 只行了非常非常差,為什麼?就是不符合理論室
# [00:38.000 --> 00:46.000] 一個病,你分幾個是跟兩個階段相結合,每個階段對於什麼法案,你怎麼調態長大法案不起床
# [00:47.000 --> 00:59.000] 因爲的非常差,所以我經常說,事有與者東方三年變為天下,無病可治
# [00:59.000 --> 01:03.000] 即知病三年來之天下,無方可用
# [01:03.000 --> 01:11.000] 我要問你,你覺得,需要知病,中醫變症,自覺無病無知
# [01:11.000 --> 01:17.000] 糖漏不用需要,中醫單剛變累,變問何方可
# [01:17.000 --> 01:25.000] 你現在醫療已經跟古代完全不一樣,你現在是你不看的科科指標,病人還看
# [01:25.000 --> 01:32.000] 病人看幾次科科指標沒效果,不來找你的,所以說我們缺乏大法的藥
# [01:32.000 --> 01:36.000] 這個現在先搞標準標準標準標準標準標準,變成都是什麼搞標準
# [01:36.000 --> 01:42.000] 變成都是本人意義的一方,所以說要搞標準,要搞太罰辨識
# [01:42.000 --> 01:45.000] 才真正能夠搞出了中醫的標準
# ...
